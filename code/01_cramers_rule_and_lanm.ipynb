# %%
#cramers rule

while(1):
    c=int(input("Enter numbe of colmn :"))
    r=int(input("Ente number of rows : "))
    a=[[int(input("Enter element of co-efficeient of matrices :"))for x in range (c)]for y in range (r)]
    b=[]
    for i in range (c):
        b.append(int(input("Enter solution set :")))
        print(b)
    
    d=(a[0][0]*a[1][1])-(a[0][1]*a[1][0])
    if d==0:
        print("determinant is zero can not use cramers")
        choice=input("Do you want to continue")
        if choice=='yes':
            continue
        else:
            print("Thank you")
            break
    else:
        d1=(b[0]*a[1][1])-(b[1]*a[0][1])
        d2=(b[1]*a[0][0])-(b[0]*a[1][0])
        x1=d1/d
        x2=d2/d
        print("Sol of x1",x1)
        print("Sol of x2",x2)
        choice=input("Do you want to continue")
        if choice=='yes':
            continue
        else:
            print("Thank you")
            break
# Out:
# Enter numbe of colmn :2
# Ente number of rows : 2
# Enter element of co-efficeient of matrices :2
# Enter element of co-efficeient of matrices :3
# Enter element of co-efficeient of matrices :4
# Enter element of co-efficeient of matrices :5
# Enter solution set :2
# [2]
# Enter solution set :3
# [2, 3]
# Sol of x1 -0.5
# Sol of x2 1.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 28
#      26 print("Sol of x1",x1)
#      27 print("Sol of x2",x2)
# ---> 28 choice=input("Do you want to continue")
#      29 if choice=='yes':
#      30     continue
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1202, in Kernel.raw_input(self, prompt)
#    1200     msg = "raw_input was called, but this frontend does not support input requests."
#    1201     raise StdinNotImplementedError(msg)
# -> 1202 return self._input_request(
#    1203     str(prompt),
# ...

# %%
#addition

while(1):
    c1=int(input("Enter number of column for 1st matrice :"))
    r1=int(input("Enter number of rows for 1st matrice :"))
    c2=int(input("Enter number of column for 2nd matrice :"))
    r2=int(input("Enter number of rows for 2nd matrice :"))
    
    if c1!=c2 or r1!=r2:
        print("rows and column of matrices are not matching")
        choice=input("Do you want to continue")
        if choice=='yes':
            continue
        else:
            print("Thank you")
            break
    else:
        a=[[int(input("Enter elements of 1st matrices : "))for x in range (c1)]for y in range (r1)]
        b=[[int(input("Enter elements of 2nd matrices : "))for x in range (c2)]for y in range (r2)]
        print("First matrices")
        for i in range (r1):
            for j in range (c1):
                print("\t",a[i][j],end="")
                print()
        print()
        print("Second matrices")
        for i in range (r2):
            for j in range (c2):
                print("\t",b[i][j],end="")
                print()
        print()
        print("addition")
        for i in range(r1):
            for i in range (c1):
                print(a[i][j]+b[i][j],"\t",end="")
                print()
        choice=input("Do you want to continue")
        if choice=='yes':
            continue
        else:
            print("Thank you")
            break
# Out:
# Enter number of column for 1st matrice :2
# Enter number of rows for 1st matrice :2
# Enter number of column for 2nd matrice :2
# Enter number of rows for 2nd matrice :2
# Enter elements of 1st matrices : 1
# Enter elements of 1st matrices : 2
# Enter elements of 1st matrices : 3
# Enter elements of 1st matrices : 4
# Enter elements of 2nd matrices : 5
# Enter elements of 2nd matrices : 6
# Enter elements of 2nd matrices : 7
# Enter elements of 2nd matrices : 8
# First matrices
# 	 1
# 	 2
# 	 3
# 	 4
#
# Second matrices
# 	 5
# 	 6
# 	 7
# 	 8
#
# addition
# 8
# 12
# 8
# 12
# Do you want to continueno
# Thank you

# %%
#bisection x*x*x-9*x+1 (a,f(a),b,f(b),c,f(c),difference)

import math
def f(x):
    a=x*x*x-9*x+1
    return(a)

a=float(input("Enter your first point : "))
b=float(input("Enter your second point :"))

if f(a)*f(b)>0:
    print("Root does not exit between a:",a,"and b:",b)
else:
    E=float(input("Enter value for epsloan"))
    c=0
    print("Tabular form")
    print("\ta\t\tf(a)\t\tb\t\tf(b)\t\tc\t\tf(c)\t\tdifference")
    print("------------------------------------------------------")
    diff=1
    e=0
    while(True):
        c=(a+b)/2
        diff=abs(c-e)
        print("\t{:.5}".format(a),"\t{:.5}".format(f(a)),"\t{:.5}".format(b),"\t{:.5}".format(f(b)),"\t{:.5}".format(c),"\t{:.5}".format(f(c)),"\t{:.5}".format(diff))
        if f(a)*f(c)<0:
            b=c
        else:
            a=c
        if diff<E:
            break
        else:
            e=c
            continue
# Out:
# Enter your first point : 2
# Enter your second point :3
# Enter value for epsloan0.001
# Tabular form
# 	a		f(a)		b		f(b)		c		f(c)		difference
# ------------------------------------------------------
# 	2.0 	-9.0 	3.0 	1.0 	2.5 	-5.875 	2.5
# 	2.5 	-5.875 	3.0 	1.0 	2.75 	-2.9531 	0.25
# 	2.75 	-2.9531 	3.0 	1.0 	2.875 	-1.1113 	0.125
# 	2.875 	-1.1113 	3.0 	1.0 	2.9375 	-0.090088 	0.0625
# 	2.9375 	-0.090088 	3.0 	1.0 	2.9688 	0.44626 	0.03125
# 	2.9375 	-0.090088 	2.9688 	0.44626 	2.9531 	0.17592 	0.015625
# 	2.9375 	-0.090088 	2.9531 	0.17592 	2.9453 	0.042378 	0.0078125
# 	2.9375 	-0.090088 	2.9453 	0.042378 	2.9414 	-0.02399 	0.0039062
# 	2.9414 	-0.02399 	2.9453 	0.042378 	2.9434 	0.0091605 	0.0019531
# 	2.9414 	-0.02399 	2.9434 	0.0091605 	2.9424 	-0.007423 	0.00097656

# %%
#bisection x*x*x-9*x+1 (a,f(a),b,f(b),c,f(c),difference)

import math
def f(x):
    a=x*x*x-9*x+1
    return(a)

a=float(input("Enter your first point : "))
b=float(input("Enter your second point :"))

if f(a)*f(b)>0:
    print("Root does not exit between a:",a,"and b:",b)
else:
    E=float(input("Enter value for epsloan"))
    c=0
    print("Tabular form")
    print("\ta\t\tf(a)\t\tb\t\tf(b)\t\tc\t\tf(c)\t\tdifference")
    print("------------------------------------------------------")
    diff=1
    e=0
    while(True):
        c=((a*f(b)-b*f(a))/(f(b)-f(a)))
        diff=abs(c-e)
        print("\t{:.5f}".format(a),"\t{:.5f}".format(f(a)),"\t{:.5f}".format(b),"\t{:.5f}".format(f(b)),"\t{:.5f}".format(c),"\t{:.5f}".format(f(c)),"\t{:.5f}".format(diff))
        if f(a)*f(c)<0:
            b=c
        else:
            a=c
        if diff<E:
            break
        else:
            e=c
            continue
# Out:
# Enter your first point : 2
# Enter your second point :3
# Enter value for epsloan0.001
# Tabular form
# 	a		f(a)		b		f(b)		c		f(c)		difference
# ------------------------------------------------------
# 	2.00000 	-9.00000 	3.00000 	1.00000 	2.90000 	-0.71100 	2.90000
# 	2.90000 	-0.71100 	3.00000 	1.00000 	2.94155 	-0.02147 	0.04155
# 	2.94155 	-0.02147 	3.00000 	1.00000 	2.94278 	-0.00062 	0.00123
# 	2.94278 	-0.00062 	3.00000 	1.00000 	2.94282 	-0.00002 	0.00004

# %%
#cramers rule

while(1):
    c=int(input("Enter number of columns : "))
    r=int(input("Enter number of rows : "))
    a=[[int(input("Enter element of co-efficient :"))for x in range(c)]for y in range(r)]
    b=[]
    for i in range (c):
        b.append(int(input("Enter solution set :")))
        print (b)
        
    d=(a[0][0]*a[1][1])-(a[0][1]*a[1][0])
    
    if d==0:
        print("determinant is zero so can not use cramers rule")
        choice=input("Do you want to continue")
        if choice=='yes':
            continue
        else:
            print("Thanku you")
            break
        
    else:
        d1=(b[0]*a[1][1])-(b[1]*a[0][1])
        d2=(b[1]*a[0][0])-(b[0]*a[1][0])
        x1=d1/d
        x2=d2/d
        print("solution of x1 is: ",x1)
        print("solution of x2 is: ",x2)
        choice=input("Do you want to continue")
        if choice=='yes':
            continue
        else:
            print("Thanku you")
            break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 4
#       1 #cramers rule
#       3 while(1):
# ----> 4     c=int(input("Enter number of columns : "))
#       5     r=int(input("Enter number of rows : "))
#       6     a=[[int(input("Enter element of co-efficient :"))for x in range(c)]for y in range(r)]
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1202, in Kernel.raw_input(self, prompt)
#    1200     msg = "raw_input was called, but this frontend does not support input requests."
#    1201     raise StdinNotImplementedError(msg)
# -> 1202 return self._input_request(
#    1203     str(prompt),
#    1204     self._parent_ident["shell"],
#    1205     self.get_parent("shell"),
#    1206     password=False,
#    1207 )
#
# ...

# %%
#determinant

while(1):
    c=int(input("Enter number of column : "))
    r=int(input("Enter number of rows : "))
    
    if c!=r:
        print("rows and columns are not same.")
        choice=input("Do you want to continue")
        if choice=='yes':
            continue
        else:
            print("Thanku you")
            break
    else:
        a=[[int(input("Enter element: "))for x in range(c)]for y in range(r)]
        d=(a[0][0]*a[1][1])-(a[0][1]*a[1][0])
        print("Determinant of matrix is :",d)
        choice=input("Do you want to continue")
        if choice=='yes':
            continue
        else:
            print("Thanku you")
            break
# Out:
# Enter number of column : 2
# Enter number of rows : 2
# Enter element: 1
# Enter element: 2
# Enter element: 3
# Enter element: 4
# Determinant of matrix is : -2
# Do you want to continueyes
# Enter number of column : 3
# Enter number of rows : 3
# Enter element: 2
# Enter element: 3
# Enter element: 4
# Enter element: 5
# Enter element: 6
# Enter element: 7
# Enter element: 8
# Enter element: 9
# Enter element: 1
# Determinant of matrix is : -3
# Do you want to continueno
# Thanku you

# %%
#addition 

while (1):
    c1=int(input("enter number of columns of 1st matric: "))
    r1=int(input("Enter number of 1st rows of matric: "))
    c2=int(input("enter number of columns of 2nd matric: "))
    r2=int(input("Enter number of rows of 2nd matric: "))
    
    if c1!=c2 or r1!=r2:
        print("rows and column are not matching")
        choice=input("Do you want to continue")
        if choice=='yes':
            continue
        else:
            print("Thanku you")
            break
    else:
        a=[[int(input("Enter elements of 1st matrices"))for x in range (c1)]for y in range(r1)]
        b=[[int(input("Enter elements of 2nd matrices"))for x in range (c2)]for y in range(r2)]
        
        print("first matrix")
        for i in range(r1):
            for j in range (c1):
                print("\t",a[i][j],end="")
                print()
        print()
        print("second matrix")
        for i in range(r2):
            for j in range(c2):
                print("\t",b[i][j],end="")
                print()
        print()
        print("Addition of matrix")
        for i in range (r1):
            for j in range(c1):
                print(a[i][j]+b[i][j],"\t",end="")
                print()
        print()
        choice=input("Do you want to continue")
        if choice=='yes':
            continue
        else:
            print("Thanku you")
            break
# Out:
# enter number of columns of 1st matric: 2
# Enter number of 1st rows of matric: 2
# enter number of columns of 2nd matric: 2
# Enter number of rows of 2nd matric: 2
# Enter elements of 1st matrices1
# Enter elements of 1st matrices2
# Enter elements of 1st matrices3
# Enter elements of 1st matrices4
# Enter elements of 2nd matrices3
# Enter elements of 2nd matrices4
# Enter elements of 2nd matrices5
# Enter elements of 2nd matrices6
# first matrix
# 	 1
# 	 2
# 	 3
# 	 4
#
# second matrix
# 	 3
# 	 4
# 	 5
# 	 6
#
# Addition of matrix
# 4
# 6
# 8
# 10
#
# Do you want to continueno
# Thanku you
